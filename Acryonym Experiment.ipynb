# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel('bp_fp_favorite.xlsx', header=None)

column_index = 4

# Filter rows where the specified column is empty
empty_samples = df[df.iloc[:, column_index].isna()].sample(n=min(400, df[df.iloc[:, column_index].isna()].shape[0]))

# Filter rows where the specified column is not empty
non_empty_samples = df[df.iloc[:, column_index].notna()].sample(n=min(100, df[df.iloc[:, column_index].notna()].shape[0]))

# Combine the samples
combined_samples = pd.concat([empty_samples, non_empty_samples])

# If you need to reset the index
combined_samples.reset_index(drop=True, inplace=True)

# Optionally, save the combined samples to a new Excel file
combined_samples.to_excel('sampled_data.xlsx', index=False)

# %%
import pandas as pd

# Load the Excel file without headers 
df = pd.read_excel('sampled_data.xlsx')

column_index_1 = 4  # category
column_index_2 = 6  # posts

# Create a list of tuples (pairs) from the two columns
pairs = list(zip(df.iloc[:, column_index_1], df.iloc[:, column_index_2]))

# # Loop over each pair and print it
# for pair in pairs:
#     print(pair)

# %%
import json

file_name = "acryonym_experiment_3.json"

def save_progress_and_responses(last_processed_index, responses):
    with open(file_name, 'w') as file:
        data = {
            'last_processed_index': last_processed_index,
            'responses': responses
        }
        json.dump(data, file)


def load_progress_and_responses():
    try:
        with open(file_name, 'r') as file:
            data = json.load(file)
            return data['last_processed_index'], data['responses']
    except FileNotFoundError:
        return -1, []  # No progress file, start from the beginning

    
import openai
  
api_key = ""
client = openai.OpenAI(api_key=api_key)


# Load the last processed index and existing responses
last_processed_index, responses = load_progress_and_responses()

# Loop through each user post starting from the last processed index
for i in range(last_processed_index + 1, len(pairs)):
    post = pairs[i][1]

    print(f"Processing post: {i + 1}/{len(pairs)}")
    print(len(post))
    
    response = client.chat.completions.create(
        model="gpt-4-1106-preview",
        messages=[
            {
                "role": "system",
                "content": "You are an Adoption Agent who specializes in reviewing and understanding online posts relating to adoptions. The authors occasionally use acronyms or codes; here is a list of relevant ones for reference: AA: African American, Bmom or BM or **; Birth Mom, CC or CA: Caucasian, DD: Dear Daughter, DS: Dear Son, PAP: Prospective Adoptive Parent, SN: Special Needs.  Given the post, only respond yes or no to each of the first three questions:  1) is the author a birth mother, 2) has the birth mother actually given up a child for adoption, 3) did the birth mother give a reason why she chose the adoption family? Finally, if the answer to the first three questions were all yes, then respond concisely to 4) what are the main and specific reasons the adoption family was chosen, if any, choose all that apply: Salary, Age, Occupation, Race, Religion, Order of Presentation, Timing, Siblings, etc, or N/A. Example response: 1) yes 2) yes 3) yes 4) Age: older than self"
            },
            {
                "role": "user",
                "content": post[:50000]
            }
        ]
    )
    response_text = response.choices[0].message.content
    responses.append(response_text)

    # Save progress and responses every 10 posts
    if (i + 1) % 10 == 0:
        save_progress_and_responses(i, responses)
# Out:
# Processing post: 1/500
# 651
# Processing post: 2/500
# 137
# Processing post: 3/500
# 1073
# Processing post: 4/500
# 314
# Processing post: 5/500
# 458
# Processing post: 6/500
# 1057
# Processing post: 7/500
# 1834
# Processing post: 8/500
# 114
# Processing post: 9/500
# 7843
# Processing post: 10/500
# 147
# Processing post: 11/500
# 1015
# Processing post: 12/500
# 211
# Processing post: 13/500
# 1280
# Processing post: 14/500
# 8190
# Processing post: 15/500
# 27
# Processing post: 16/500
# 8191
# Processing post: 17/500
# 1476
# Processing post: 18/500
# 8191
# Processing post: 19/500
# 1588
# Processing post: 20/500
# 2869
# Processing post: 21/500
# 5454
# Processing post: 22/500
# 329
# Processing post: 23/500
# 257
# Processing post: 24/500
# 8190
# Processing post: 25/500
# 174
# Processing post: 26/500
# 252
# Processing post: 27/500
# 1905
# Processing post: 28/500
# 8191
# Processing post: 29/500
# 3446
# Processing post: 30/500
# 1517
# Processing post: 31/500
# 34
# Processing post: 32/500
# 810
# Processing post: 33/500
# 2994
# Processing post: 34/500
# 757
# Processing post: 35/500
# 8191
# Processing post: 36/500
# 8191
# Processing post: 37/500
# 1187
# Processing post: 38/500
# 5318
# Processing post: 39/500
# 1007
# Processing post: 40/500
# 8190
# Processing post: 41/500
# 694
# Processing post: 42/500
# 406
# Processing post: 43/500
# 239
# Processing post: 44/500
# 2181
# Processing post: 45/500
# 1529
# Processing post: 46/500
# 8191
# Processing post: 47/500
# 2369
# Processing post: 48/500
# 261
# Processing post: 49/500
# 1377
# Processing post: 50/500
# 449
# Processing post: 51/500
# 547
# Processing post: 52/500
# 627
# Processing post: 53/500
# 8190
# Processing post: 54/500
# 479
# Processing post: 55/500
# 639
# Processing post: 56/500
# 191
# Processing post: 57/500
# 8191
# Processing post: 58/500
# 466
# Processing post: 59/500
# 2037
# Processing post: 60/500
# 538
# Processing post: 61/500
# 2674
# Processing post: 62/500
# 504
# Processing post: 63/500
# 929
# Processing post: 64/500
# 635
# Processing post: 65/500
# 8190
# Processing post: 66/500
# 994
# Processing post: 67/500
# 478
# Processing post: 68/500
# 259
# Processing post: 69/500
# 2920
# Processing post: 70/500
# 2016
# Processing post: 71/500
# 7863
# Processing post: 72/500
# 8191
# Processing post: 73/500
# 307
# Processing post: 74/500
# 3496
# Processing post: 75/500
# 529
# Processing post: 76/500
# 622
# Processing post: 77/500
# 2605
# Processing post: 78/500
# 8190
# Processing post: 79/500
# 385
# Processing post: 80/500
# 1797
# Processing post: 81/500
# 8191
# Processing post: 82/500
# 3978
# Processing post: 83/500
# 8191
# Processing post: 84/500
# 8191
# Processing post: 85/500
# 185
# Processing post: 86/500
# 8190
# Processing post: 87/500
# 1313
# Processing post: 88/500
# 3768
# Processing post: 89/500
# 6729
# Processing post: 90/500
# 1656
# Processing post: 91/500
# 619
# Processing post: 92/500
# 8191
# Processing post: 93/500
# 551
# Processing post: 94/500
# 62
# Processing post: 95/500
# 1367
# Processing post: 96/500
# 301
# Processing post: 97/500
# 641
# Processing post: 98/500
# 720
# Processing post: 99/500
# 8191
# Processing post: 100/500
# 8190
# Processing post: 101/500
# 1331
# Processing post: 102/500
# 5066
# Processing post: 103/500
# 2247
# Processing post: 104/500
# 943
# Processing post: 105/500
# 276
# Processing post: 106/500
# 1576
# Processing post: 107/500
# 1312
# Processing post: 108/500
# 703
# Processing post: 109/500
# 369
# Processing post: 110/500
# 8191
# Processing post: 111/500
# 336
# Processing post: 112/500
# 1296
# Processing post: 113/500
# 544
# Processing post: 114/500
# 1095
# Processing post: 115/500
# 358
# Processing post: 116/500
# 4024
# Processing post: 117/500
# 1224
# Processing post: 118/500
# 8191
# Processing post: 119/500
# 402
# Processing post: 120/500
# 1555
# Processing post: 121/500
# 1721
# Processing post: 122/500
# 897
# Processing post: 123/500
# 2684
# Processing post: 124/500
# 8191
# Processing post: 125/500
# 8191
# Processing post: 126/500
# 1600
# Processing post: 127/500
# 685
# Processing post: 128/500
# 799
# Processing post: 129/500
# 1889
# Processing post: 130/500
# 3389
# Processing post: 131/500
# 389
# Processing post: 132/500
# 900
# Processing post: 133/500
# 725
# Processing post: 134/500
# 308
# Processing post: 135/500
# 2620
# Processing post: 136/500
# 587
# Processing post: 137/500
# 8191
# Processing post: 138/500
# 122
# Processing post: 139/500
# 800
# Processing post: 140/500
# 1152
# Processing post: 141/500
# 8191
# Processing post: 142/500
# 2093
# Processing post: 143/500
# 86
# Processing post: 144/500
# 8191
# Processing post: 145/500
# 157
# Processing post: 146/500
# 8191
# Processing post: 147/500
# 455
# Processing post: 148/500
# 397
# Processing post: 149/500
# 4824
# Processing post: 150/500
# 559
# Processing post: 151/500
# 4271
# Processing post: 152/500
# 674
# Processing post: 153/500
# 8191
# Processing post: 154/500
# 1518
# Processing post: 155/500
# 3060
# Processing post: 156/500
# 590
# Processing post: 157/500
# 560
# Processing post: 158/500
# 8190
# Processing post: 159/500
# 1095
# Processing post: 160/500
# 8191
# Processing post: 161/500
# 8191
# Processing post: 162/500
# 3593
# Processing post: 163/500
# 8190
# Processing post: 164/500
# 388
# Processing post: 165/500
# 482
# Processing post: 166/500
# 497
# Processing post: 167/500
# 2284
# Processing post: 168/500
# 2693
# Processing post: 169/500
# 325
# Processing post: 170/500
# 1492
# Processing post: 171/500
# 1774
# Processing post: 172/500
# 238
# Processing post: 173/500
# 1714
# Processing post: 174/500
# 8191
# Processing post: 175/500
# 2183
# Processing post: 176/500
# 1266
# Processing post: 177/500
# 478
# Processing post: 178/500
# 1430
# Processing post: 179/500
# 4157
# Processing post: 180/500
# 2410
# Processing post: 181/500
# 7528
# Processing post: 182/500
# 1039
# Processing post: 183/500
# 3693
# Processing post: 184/500
# 19
# Processing post: 185/500
# 2799
# Processing post: 186/500
# 1647
# Processing post: 187/500
# 8191
# Processing post: 188/500
# 8190
# Processing post: 189/500
# 2676
# Processing post: 190/500
# 393
# Processing post: 191/500
# 2234
# Processing post: 192/500
# 430
# Processing post: 193/500
# 240
# Processing post: 194/500
# 1403
# Processing post: 195/500
# 1752
# Processing post: 196/500
# 2227
# Processing post: 197/500
# 8191
# Processing post: 198/500
# 5411
# Processing post: 199/500
# 1858
# Processing post: 200/500
# 8191
# Processing post: 201/500
# 303
# Processing post: 202/500
# 8191
# Processing post: 203/500
# 1952
# Processing post: 204/500
# 1605
# Processing post: 205/500
# 2970
# Processing post: 206/500
# 381
# Processing post: 207/500
# 755
# Processing post: 208/500
# 8188
# Processing post: 209/500
# 768
# Processing post: 210/500
# 1227
# Processing post: 211/500
# 8190
# Processing post: 212/500
# 2942
# Processing post: 213/500
# 541
# Processing post: 214/500
# 3050
# Processing post: 215/500
# 8191
# Processing post: 216/500
# 6549
# Processing post: 217/500
# 2547
# Processing post: 218/500
# 526
# Processing post: 219/500
# 129
# Processing post: 220/500
# 8191
# Processing post: 221/500
# 3642
# Processing post: 222/500
# 8191
# Processing post: 223/500
# 966
# Processing post: 224/500
# 364
# Processing post: 225/500
# 175
# Processing post: 226/500
# 497
# Processing post: 227/500
# 241
# Processing post: 228/500
# 1132
# Processing post: 229/500
# 622
# Processing post: 230/500
# 385
# Processing post: 231/500
# 603
# Processing post: 232/500
# 8190
# Processing post: 233/500
# 2938
# Processing post: 234/500
# 926
# Processing post: 235/500
# 2101
# Processing post: 236/500
# 1768
# Processing post: 237/500
# 974
# Processing post: 238/500
# 415
# Processing post: 239/500
# 8191
# Processing post: 240/500
# 291
# Processing post: 241/500
# 3500
# Processing post: 242/500
# 764
# Processing post: 243/500
# 2587
# Processing post: 244/500
# 2054
# Processing post: 245/500
# 1065
# Processing post: 246/500
# 1542
# Processing post: 247/500
# 1231
# Processing post: 248/500
# 742
# Processing post: 249/500
# 1034
# Processing post: 250/500
# 1527
# Processing post: 251/500
# 5762
# Processing post: 252/500
# 2205
# Processing post: 253/500
# 1165
# Processing post: 254/500
# 8191
# Processing post: 255/500
# 8191
# Processing post: 256/500
# 995
# Processing post: 257/500
# 771
# Processing post: 258/500
# 2644
# Processing post: 259/500
# 297
# Processing post: 260/500
# 3444
# Processing post: 261/500
# 709
# Processing post: 262/500
# 8191
# Processing post: 263/500
# 1575
# Processing post: 264/500
# 4669
# Processing post: 265/500
# 225
# Processing post: 266/500
# 1189
# Processing post: 267/500
# 273
# Processing post: 268/500
# 2521
# Processing post: 269/500
# 117
# Processing post: 270/500
# 1706
# Processing post: 271/500
# 222
# Processing post: 272/500
# 754
# Processing post: 273/500
# 455
# Processing post: 274/500
# 2797
# Processing post: 275/500
# 375
# Processing post: 276/500
# 3879
# Processing post: 277/500
# 1185
# Processing post: 278/500
# 765
# Processing post: 279/500
# 369
# Processing post: 280/500
# 808
# Processing post: 281/500
# 150
# Processing post: 282/500
# 468
# Processing post: 283/500
# 230
# Processing post: 284/500
# 253
# Processing post: 285/500
# 8190
# Processing post: 286/500
# 394
# Processing post: 287/500
# 1115
# Processing post: 288/500
# 1629
# Processing post: 289/500
# 4309
# Processing post: 290/500
# 218
# Processing post: 291/500
# 163
# Processing post: 292/500
# 8191
# Processing post: 293/500
# 1708
# Processing post: 294/500
# 2444
# Processing post: 295/500
# 3639
# Processing post: 296/500
# 617
# Processing post: 297/500
# 3303
# Processing post: 298/500
# 8190
# Processing post: 299/500
# 1723
# Processing post: 300/500
# 141
# Processing post: 301/500
# 3344
# Processing post: 302/500
# 8191
# Processing post: 303/500
# 1227
# Processing post: 304/500
# 543
# Processing post: 305/500
# 1713
# Processing post: 306/500
# 5086
# Processing post: 307/500
# 3359
# Processing post: 308/500
# 8191
# Processing post: 309/500
# 2795
# Processing post: 310/500
# 2737
# Processing post: 311/500
# 2833
# Processing post: 312/500
# 1533
# Processing post: 313/500
# 8189
# Processing post: 314/500
# 871
# Processing post: 315/500
# 8191
# Processing post: 316/500
# 75
# Processing post: 317/500
# 523
# Processing post: 318/500
# 732
# Processing post: 319/500
# 270
# Processing post: 320/500
# 487
# Processing post: 321/500
# 114
# Processing post: 322/500
# 1289
# Processing post: 323/500
# 937
# Processing post: 324/500
# 1897
# Processing post: 325/500
# 1497
# Processing post: 326/500
# 979
# Processing post: 327/500
# 2795
# Processing post: 328/500
# 8191
# Processing post: 329/500
# 390
# Processing post: 330/500
# 8191
# Processing post: 331/500
# 8191
# Processing post: 332/500
# 673
# Processing post: 333/500
# 6675
# Processing post: 334/500
# 8191
# Processing post: 335/500
# 1111
# Processing post: 336/500
# 8191
# Processing post: 337/500
# 167
# Processing post: 338/500
# 8191
# Processing post: 339/500
# 8191
# Processing post: 340/500
# 1615
# Processing post: 341/500
# 4191
# Processing post: 342/500
# 5117
# Processing post: 343/500
# 330
# Processing post: 344/500
# 338
# Processing post: 345/500
# 8191
# Processing post: 346/500
# 946
# Processing post: 347/500
# 3470
# Processing post: 348/500
# 1702
# Processing post: 349/500
# 8191
# Processing post: 350/500
# 8191
# Processing post: 351/500
# 73
# Processing post: 352/500
# 703
# Processing post: 353/500
# 389
# Processing post: 354/500
# 335
# Processing post: 355/500
# 1728
# Processing post: 356/500
# 7490
# Processing post: 357/500
# 5771
# Processing post: 358/500
# 2346
# Processing post: 359/500
# 61
# Processing post: 360/500
# 793
# Processing post: 361/500
# 722
# Processing post: 362/500
# 8191
# Processing post: 363/500
# 474
# Processing post: 364/500
# 192
# Processing post: 365/500
# 177
# Processing post: 366/500
# 361
# Processing post: 367/500
# 1588
# Processing post: 368/500
# 70
# Processing post: 369/500
# 3372
# Processing post: 370/500
# 5143
# Processing post: 371/500
# 8191
# Processing post: 372/500
# 252
# Processing post: 373/500
# 251
# Processing post: 374/500
# 6962
# Processing post: 375/500
# 4891
# Processing post: 376/500
# 3634
# Processing post: 377/500
# 402
# Processing post: 378/500
# 1097
# Processing post: 379/500
# 1128
# Processing post: 380/500
# 41
# Processing post: 381/500
# 711
# Processing post: 382/500
# 1149
# Processing post: 383/500
# 2544
# Processing post: 384/500
# 4871
# Processing post: 385/500
# 367
# Processing post: 386/500
# 943
# Processing post: 387/500
# 500
# Processing post: 388/500
# 752
# Processing post: 389/500
# 5116
# Processing post: 390/500
# 8191
# Processing post: 391/500
# 786
# Processing post: 392/500
# 1035
# Processing post: 393/500
# 859
# Processing post: 394/500
# 208
# Processing post: 395/500
# 1901
# Processing post: 396/500
# 2699
# Processing post: 397/500
# 321
# Processing post: 398/500
# 674
# Processing post: 399/500
# 1498
# Processing post: 400/500
# 5595
# Processing post: 401/500
# 8191
# Processing post: 402/500
# 8191
# Processing post: 403/500
# 1202
# Processing post: 404/500
# 1459
# Processing post: 405/500
# 8191
# Processing post: 406/500
# 8191
# Processing post: 407/500
# 8191
# Processing post: 408/500
# 8190
# Processing post: 409/500
# 8191
# Processing post: 410/500
# 8191
# Processing post: 411/500
# 7206
# Processing post: 412/500
# 8191
# Processing post: 413/500
# 8191
# Processing post: 414/500
# 8191
# Processing post: 415/500
# 2841
# Processing post: 416/500
# 8191
# Processing post: 417/500
# 8191
# Processing post: 418/500
# 8191
# Processing post: 419/500
# 8191
# Processing post: 420/500
# 261
# Processing post: 421/500
# 8191
# Processing post: 422/500
# 3910
# Processing post: 423/500
# 8191
# Processing post: 424/500
# 8191
# Processing post: 425/500
# 1988
# Processing post: 426/500
# 8191
# Processing post: 427/500
# 8190
# Processing post: 428/500
# 4101
# Processing post: 429/500
# 4755
# Processing post: 430/500
# 152
# Processing post: 431/500
# 8191
# Processing post: 432/500
# 8191
# Processing post: 433/500
# 8191
# Processing post: 434/500
# 8191
# Processing post: 435/500
# 8191
# Processing post: 436/500
# 5772
# Processing post: 437/500
# 8191
# Processing post: 438/500
# 7030
# Processing post: 439/500
# 3116
# Processing post: 440/500
# 1372
# Processing post: 441/500
# 8191
# Processing post: 442/500
# 8191
# Processing post: 443/500
# 8190
# Processing post: 444/500
# 8190
# Processing post: 445/500
# 881
# Processing post: 446/500
# 3482
# Processing post: 447/500
# 8191
# Processing post: 448/500
# 8191
# Processing post: 449/500
# 8191
# Processing post: 450/500
# 8190
# Processing post: 451/500
# 8191
# Processing post: 452/500
# 2806
# Processing post: 453/500
# 8191
# Processing post: 454/500
# 8191
# Processing post: 455/500
# 8191
# Processing post: 456/500
# 2181
# Processing post: 457/500
# 8190
# Processing post: 458/500
# 8191
# Processing post: 459/500
# 3301
# Processing post: 460/500
# 8191
# Processing post: 461/500
# 8191
# Processing post: 462/500
# 8190
# Processing post: 463/500
# 8191
# Processing post: 464/500
# 2333
# Processing post: 465/500
# 8191
# Processing post: 466/500
# 5
# Processing post: 467/500
# 8191
# Processing post: 468/500
# 2024
# Processing post: 469/500
# 8191
# Processing post: 470/500
# 8191
# Processing post: 471/500
# 8191
# Processing post: 472/500
# 8191
# Processing post: 473/500
# 8191
# Processing post: 474/500
# 8190
# Processing post: 475/500
# 799
# Processing post: 476/500
# 8191
# Processing post: 477/500
# 8191
# Processing post: 478/500
# 6872
# Processing post: 479/500
# 2589
# Processing post: 480/500
# 8190
# Processing post: 481/500
# 605
# Processing post: 482/500
# 8191
# Processing post: 483/500
# 8191
# Processing post: 484/500
# 8191
# Processing post: 485/500
# 8191
# Processing post: 486/500
# 8191
# Processing post: 487/500
# 8191
# Processing post: 488/500
# 1470
# Processing post: 489/500
# 1268
# Processing post: 490/500
# 8190
# Processing post: 491/500
# 8191
# Processing post: 492/500
# 4296
# Processing post: 493/500
# 622
# Processing post: 494/500
# 8191
# Processing post: 495/500
# 8191
# Processing post: 496/500
# 596
# Processing post: 497/500
# 8191
# Processing post: 498/500
# 8191
# Processing post: 499/500
# 1510
# Processing post: 500/500
# 8191

# %%
# for r in responses:
#     print(r)

# %%
import pandas as pd

# Assuming 'pairs' is your list of pairs from the previous step
# And 'outputs' is your new list with the corresponding outputs
# Example:
# pairs = [(1, 2), (3, 4), ...]
# outputs = [5, 7, ...]

# Verify the lists have the same length
assert len(pairs) == len(responses), "The lists must have the same length"

# Combine the pairs and outputs into a single DataFrame
df_combined = pd.DataFrame({
    'Post': [pair[1] for pair in pairs],
    'Original category': [pair[0] for pair in pairs],
    'Acryontm catefory': responses
})

# Save to a new Excel file
df_combined.to_excel('acryonym_results_3.xlsx', index=False)
